# %% [markdown]
# # Autofit Programme

# %% [markdown]
# #### Can I build a programme which can take an arbitrary number of users and fit their data to models of my choosing?
# #### Goal: be able to quickly assess which models are good at detecting one user's actions vs. all the others.

# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split

from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

from sklearn.metrics import classification_report, confusion_matrix

import warnings
warnings.filterwarnings("ignore")

# %%
actions = pd.read_csv("../../data/processed_balabit_data.csv")
actions.head()
# Out:
#    traveled_distance_pixel  elapsed_time  straightness  num_points  \
# 0              2596.537181         9.329      0.198032          82
# 1               179.260212         1.919      0.959645          14
# 2               887.903498         2.137      0.979540          21
# 3                75.035669         1.358      0.999613           7
# 4              1078.673940         3.541      0.949591          27
#
#    sum_of_angles  mean_curv   sd_curv  max_curv  min_curv  mean_omega  ...  \
# 0      56.525861  -0.085272  0.527422  1.091459 -3.141593   15.669106  ...
# 1      11.255258  -0.235679  0.916836  0.314159 -3.141593  -10.058717  ...
# 2     -14.268377  -0.078308  0.112436  0.261799 -1.570796   -5.221251  ...
# 3      -0.071307  -0.000650  0.002580  0.001828 -0.005080    0.052710  ...
# 4     -24.025555  -0.040986  0.174415  0.249828 -0.628390    4.743248  ...
#
#    action_3  action_4  direction_1  direction_2  direction_3  direction_4  \
# 0         0         0            0            0            1            0
# 1         0         1            0            1            0            0
# 2         0         0            0            0            0            0
# 3         0         1            0            0            0            0
# 4         1         0            0            0            0            1
#
#    direction_5  direction_6  direction_7  user
# 0            0            0            0    12
# 1            0            0            0    12
# 2            0            0            1    12
# 3            0            0            1    12
# 4            0            0            0    12
#
# [5 rows x 47 columns]

# %%
# renaming the users to ensure uniqueness of user ID
actions["user"] = actions["user"] + 100

# %%
# list of all users
user_names = ["user"+str(num) for num in list(actions["user"].unique())]

# %%
# function to create user columns
def user_maker(data, column="user"):
    for i in list(data[column].unique()):
        data[column+str(i)] = [1 if j == i else 0 for j in data[column]]

# %%
user_maker(actions)

# %%
# function to create user specific column indexes

col = []

def index_maker(data, column="user"):
    for user in user_names:
        col.append(data.columns.difference([j for j in data.columns if ((str(user) not in j) & ("user" in j))]))

# %%
index_maker(actions)

# %%
col_indexer = dict(zip(user_names, col))

# %%
# function to select all user-specific actions and a random sample of other users' actions, joining the two in one user-specific dataframe for each user
dataframes = []

def row_selector(data):
    for user in user_names:
        df = data[data[user]==1].append(data[actions[user]==0].sample(n=len(data[data[user]==1]))).reset_index(drop=True)
        dataframes.append(df)

# %%
row_selector(actions)

# %%
user_mapper = dict(zip(user_names, dataframes))

# %%
# function to select columns specific to an individual user
user_dataframes = []

def col_selector(dictionary, indexer=col_indexer):
    for user in user_names:
        df = dictionary[user][col_indexer[user]]
        user_dataframes.append(df)
        
    final_data = dict(zip(user_names, user_dataframes))
    
    return final_data

# %%
final_data = col_selector(user_mapper)

# %%
#check shape of each dataframe in the "final_data" dictionary and check the user corresponds to the correct indexer
for i in user_names:
    print(i, final_data[i].shape)
    # print(final_data[i].columns)
# Out:
# user112 (15310, 47)
# user115 (14304, 47)
# user116 (21534, 47)
# user120 (7618, 47)
# user121 (11534, 47)
# user123 (10880, 47)
# user129 (14534, 47)
# user135 (8450, 47)
# user107 (11148, 47)
# user109 (6498, 47)

# %%
# check how many data points there should be for each user
for i in user_names:
    print(len(actions[actions[i]==1])*2)
# Out:
# 15310
# 14304
# 21534
# 7618
# 11534
# 10880
# 14534
# 8450
# 11148
# 6498

# %%
# function to fit any model to any user's data
def model_fitter(user, model, dict_of_data=final_data, test_size=0.3, random_state=42):
    
    features = dict_of_data[str(user)].drop(str(user), axis=1)
    labels = dict_of_data[str(user)][str(user)]
    
    training_data, test_data, training_labels, test_labels = train_test_split(features,
                                                                              labels,
                                                                              test_size=test_size,
                                                                              random_state=random_state)
    
    clf = model()
    clf.fit(training_data, training_labels)
    
    pred = clf.predict(test_data)
    performance = classification_report(test_labels, pred)
    performance_2 = confusion_matrix(test_labels, pred)
    
    print("Model used:", model, "\n")
    print(performance)
    print(performance_2)

# %%
models = [KNeighborsClassifier, RandomForestClassifier, LogisticRegression, SVC]

# %%
for user in user_names:
    for model in models:
        print("\nUser:", user, "\n")
        model_fitter(user=user, model=model)
# Out:
# User: user112
#
# Model used: <class 'sklearn.neighbors.classification.KNeighborsClassifier'>
#
#               precision    recall  f1-score   support
#
#            0       0.62      0.58      0.60      2311
#            1       0.60      0.65      0.62      2282
#
#     accuracy                           0.61      4593
#    macro avg       0.61      0.61      0.61      4593
# weighted avg       0.61      0.61      0.61      4593
#
# [[1340  971]
#  [ 805 1477]]
#
# User: user112
#
# Model used: <class 'sklearn.ensemble.forest.RandomForestClassifier'>
#
#               precision    recall  f1-score   support
#
#            0       0.69      0.75      0.71      2311
#            1       0.72      0.66      0.69      2282
#
#     accuracy                           0.70      4593
#    macro avg       0.70      0.70      0.70      4593
# weighted avg       0.70      0.70      0.70      4593
#
# [[1722  589]
#  [ 786 1496]]
#
# User: user112
#
# Model used: <class 'sklearn.linear_model.logistic.LogisticRegression'>
#
#               precision    recall  f1-score   support
#
#            0       0.74      0.53      0.61      2311
#            1       0.63      0.81      0.71      2282
#
#     accuracy                           0.67      4593
#    macro avg       0.68      0.67      0.66      4593
# weighted avg       0.68      0.67      0.66      4593
#
# [[1215 1096]
#  [ 437 1845]]
#
# User: user112
#
# Model used: <class 'sklearn.svm.classes.SVC'>
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      2311
#            1       0.50      1.00      0.66      2282
#
#     accuracy                           0.50      4593
#    macro avg       0.25      0.50      0.33      4593
# weighted avg       0.25      0.50      0.33      4593
#
# [[   0 2311]
#  [   0 2282]]
#
# User: user115
#
# Model used: <class 'sklearn.neighbors.classification.KNeighborsClassifier'>
#
#               precision    recall  f1-score   support
#
#            0       0.62      0.58      0.60      2158
#            1       0.60      0.64      0.62      2134
#
#     accuracy                           0.61      4292
#    macro avg       0.61      0.61      0.61      4292
# weighted avg       0.61      0.61      0.61      4292
#
# [[1249  909]
#  [ 770 1364]]
#
# User: user115
#
# Model used: <class 'sklearn.ensemble.forest.RandomForestClassifier'>
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.74      0.72      2158
#            1       0.72      0.67      0.70      2134
#
#     accuracy                           0.71      4292
#    macro avg       0.71      0.71      0.71      4292
# weighted avg       0.71      0.71      0.71      4292
#
# [[1607  551]
#  [ 697 1437]]
#
# User: user115
#
# Model used: <class 'sklearn.linear_model.logistic.LogisticRegression'>
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.22      0.34      2158
#            1       0.55      0.95      0.69      2134
#
#     accuracy                           0.58      4292
#    macro avg       0.68      0.58      0.52      4292
# weighted avg       0.68      0.58      0.52      4292
#
# [[ 472 1686]
#  [ 111 2023]]
#
# User: user115
#
# Model used: <class 'sklearn.svm.classes.SVC'>
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      2158
#            1       0.50      1.00      0.66      2134
#
#     accuracy                           0.50      4292
#    macro avg       0.25      0.50      0.33      4292
# weighted avg       0.25      0.50      0.33      4292
#
# [[   0 2158]
#  [   0 2134]]
#
# User: user116
#
# Model used: <class 'sklearn.neighbors.classification.KNeighborsClassifier'>
#
#               precision    recall  f1-score   support
#
#            0       0.60      0.55      0.57      3214
#            1       0.59      0.64      0.61      3247
#
#     accuracy                           0.60      6461
#    macro avg       0.60      0.59      0.59      6461
# weighted avg       0.60      0.60      0.59      6461
#
# [[1756 1458]
#  [1158 2089]]
#
# User: user116
#
# Model used: <class 'sklearn.ensemble.forest.RandomForestClassifier'>
#
#               precision    recall  f1-score   support
#
#            0       0.64      0.70      0.67      3214
#            1       0.67      0.61      0.64      3247
#
#     accuracy                           0.65      6461
#    macro avg       0.66      0.65      0.65      6461
# weighted avg       0.66      0.65      0.65      6461
#
# [[2249  965]
#  [1273 1974]]
#
# User: user116
#
# Model used: <class 'sklearn.linear_model.logistic.LogisticRegression'>
#
#               precision    recall  f1-score   support
#
#            0       0.72      0.36      0.48      3214
#            1       0.58      0.86      0.69      3247
#
#     accuracy                           0.61      6461
#    macro avg       0.65      0.61      0.59      6461
# weighted avg       0.65      0.61      0.59      6461
#
# [[1164 2050]
#  [ 443 2804]]
#
# User: user116
#
# Model used: <class 'sklearn.svm.classes.SVC'>
#
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.66      3214
#            1       0.00      0.00      0.00      3247
#
#     accuracy                           0.50      6461
#    macro avg       0.25      0.50      0.33      6461
# weighted avg       0.25      0.50      0.33      6461
#
# [[3214    0]
#  [3247    0]]
#
# User: user120
#
# Model used: <class 'sklearn.neighbors.classification.KNeighborsClassifier'>
#
#               precision    recall  f1-score   support
#
#            0       0.66      0.68      0.67      1122
#            1       0.68      0.67      0.68      1164
#
#     accuracy                           0.67      2286
#    macro avg       0.67      0.67      0.67      2286
# weighted avg       0.67      0.67      0.67      2286
#
# [[758 364]
#  [384 780]]
#
# User: user120
#
# Model used: <class 'sklearn.ensemble.forest.RandomForestClassifier'>
#
#               precision    recall  f1-score   support
#
#            0       0.69      0.79      0.74      1122
#            1       0.76      0.65      0.70      1164
#
#     accuracy                           0.72      2286
#    macro avg       0.73      0.72      0.72      2286
# weighted avg       0.73      0.72      0.72      2286
#
# [[888 234]
#  [405 759]]
#
# User: user120
#
# Model used: <class 'sklearn.linear_model.logistic.LogisticRegression'>
#
#               precision    recall  f1-score   support
#
#            0       0.55      0.87      0.68      1122
#            1       0.72      0.33      0.45      1164
#
#     accuracy                           0.59      2286
#    macro avg       0.64      0.60      0.56      2286
# weighted avg       0.64      0.59      0.56      2286
#
# [[973 149]
#  [783 381]]
#
# User: user120
#
# Model used: <class 'sklearn.svm.classes.SVC'>
#
#               precision    recall  f1-score   support
#
#            0       0.49      1.00      0.66      1122
#            1       0.00      0.00      0.00      1164
#
#     accuracy                           0.49      2286
#    macro avg       0.25      0.50      0.33      2286
# weighted avg       0.24      0.49      0.32      2286
#
# [[1122    0]
#  [1164    0]]
#
# User: user121
#
# Model used: <class 'sklearn.neighbors.classification.KNeighborsClassifier'>
#
#               precision    recall  f1-score   support
#
#            0       0.59      0.59      0.59      1704
#            1       0.60      0.60      0.60      1757
#
#     accuracy                           0.60      3461
#    macro avg       0.60      0.60      0.60      3461
# weighted avg       0.60      0.60      0.60      3461
#
# [[1003  701]
#  [ 699 1058]]
#
# User: user121
#
# Model used: <class 'sklearn.ensemble.forest.RandomForestClassifier'>
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.74      0.70      1704
#            1       0.71      0.64      0.68      1757
#
#     accuracy                           0.69      3461
#    macro avg       0.69      0.69      0.69      3461
# weighted avg       0.69      0.69      0.69      3461
#
# [[1254  450]
#  [ 629 1128]]
#
# User: user121
#
# Model used: <class 'sklearn.linear_model.logistic.LogisticRegression'>
#
#               precision    recall  f1-score   support
#
#            0       0.56      0.81      0.66      1704
#            1       0.68      0.39      0.50      1757
#
#     accuracy                           0.60      3461
#    macro avg       0.62      0.60      0.58      3461
# weighted avg       0.62      0.60      0.58      3461
#
# [[1378  326]
#  [1065  692]]
#
# User: user121
#
# Model used: <class 'sklearn.svm.classes.SVC'>
#
#               precision    recall  f1-score   support
#
#            0       0.49      1.00      0.66      1704
#            1       0.00      0.00      0.00      1757
#
#     accuracy                           0.49      3461
#    macro avg       0.25      0.50      0.33      3461
# weighted avg       0.24      0.49      0.32      3461
#
# [[1704    0]
#  [1757    0]]
#
# User: user123
#
# Model used: <class 'sklearn.neighbors.classification.KNeighborsClassifier'>
#
#               precision    recall  f1-score   support
#
#            0       0.64      0.60      0.61      1631
#            1       0.62      0.66      0.64      1633
#
#     accuracy                           0.63      3264
#    macro avg       0.63      0.63      0.63      3264
# weighted avg       0.63      0.63      0.63      3264
#
# [[ 971  660]
#  [ 556 1077]]
#
# User: user123
#
# Model used: <class 'sklearn.ensemble.forest.RandomForestClassifier'>
#
#               precision    recall  f1-score   support
#
#            0       0.66      0.72      0.69      1631
#            1       0.69      0.64      0.66      1633
#
#     accuracy                           0.68      3264
#    macro avg       0.68      0.68      0.68      3264
# weighted avg       0.68      0.68      0.68      3264
#
# [[1169  462]
#  [ 594 1039]]
#
# User: user123
#
# Model used: <class 'sklearn.linear_model.logistic.LogisticRegression'>
#
#               precision    recall  f1-score   support
#
#            0       0.54      0.78      0.63      1631
#            1       0.59      0.33      0.42      1633
#
#     accuracy                           0.55      3264
#    macro avg       0.56      0.55      0.53      3264
# weighted avg       0.56      0.55      0.53      3264
#
# [[1267  364]
#  [1101  532]]
#
# User: user123
#
# Model used: <class 'sklearn.svm.classes.SVC'>
#
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67      1631
#            1       0.00      0.00      0.00      1633
#
#     accuracy                           0.50      3264
#    macro avg       0.25      0.50      0.33      3264
# weighted avg       0.25      0.50      0.33      3264
#
# [[1631    0]
#  [1633    0]]
#
# User: user129
#
# Model used: <class 'sklearn.neighbors.classification.KNeighborsClassifier'>
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.72      0.73      2177
#            1       0.73      0.73      0.73      2184
#
#     accuracy                           0.73      4361
#    macro avg       0.73      0.73      0.73      4361
# weighted avg       0.73      0.73      0.73      4361
#
# [[1574  603]
#  [ 584 1600]]
#
# User: user129
#
# Model used: <class 'sklearn.ensemble.forest.RandomForestClassifier'>
#
#               precision    recall  f1-score   support
#
#            0       0.74      0.82      0.78      2177
#            1       0.80      0.72      0.76      2184
#
#     accuracy                           0.77      4361
#    macro avg       0.77      0.77      0.77      4361
# weighted avg       0.77      0.77      0.77      4361
#
# [[1784  393]
#  [ 617 1567]]
#
# User: user129
#
# Model used: <class 'sklearn.linear_model.logistic.LogisticRegression'>
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.93      0.78      2177
#            1       0.89      0.54      0.67      2184
#
#     accuracy                           0.74      4361
#    macro avg       0.78      0.74      0.73      4361
# weighted avg       0.78      0.74      0.73      4361
#
# [[2029  148]
#  [ 996 1188]]
#
# User: user129
#
# Model used: <class 'sklearn.svm.classes.SVC'>
#
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67      2177
#            1       0.00      0.00      0.00      2184
#
#     accuracy                           0.50      4361
#    macro avg       0.25      0.50      0.33      4361
# weighted avg       0.25      0.50      0.33      4361
#
# [[2177    0]
#  [2184    0]]
#
# User: user135
#
# Model used: <class 'sklearn.neighbors.classification.KNeighborsClassifier'>
#
#               precision    recall  f1-score   support
#
#            0       0.61      0.54      0.57      1265
#            1       0.59      0.66      0.62      1270
#
#     accuracy                           0.60      2535
#    macro avg       0.60      0.60      0.60      2535
# weighted avg       0.60      0.60      0.60      2535
#
# [[683 582]
#  [432 838]]
#
# User: user135
#
# Model used: <class 'sklearn.ensemble.forest.RandomForestClassifier'>
#
#               precision    recall  f1-score   support
#
#            0       0.63      0.69      0.66      1265
#            1       0.66      0.60      0.63      1270
#
#     accuracy                           0.64      2535
#    macro avg       0.65      0.65      0.64      2535
# weighted avg       0.65      0.64      0.64      2535
#
# [[871 394]
#  [506 764]]
#
# User: user135
#
# Model used: <class 'sklearn.linear_model.logistic.LogisticRegression'>
#
#               precision    recall  f1-score   support
#
#            0       0.49      0.95      0.65      1265
#            1       0.31      0.02      0.04      1270
#
#     accuracy                           0.48      2535
#    macro avg       0.40      0.49      0.35      2535
# weighted avg       0.40      0.48      0.34      2535
#
# [[1198   67]
#  [1240   30]]
#
# User: user135
#
# Model used: <class 'sklearn.svm.classes.SVC'>
#
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67      1265
#            1       0.00      0.00      0.00      1270
#
#     accuracy                           0.50      2535
#    macro avg       0.25      0.50      0.33      2535
# weighted avg       0.25      0.50      0.33      2535
#
# [[1265    0]
#  [1270    0]]
#
# User: user107
#
# Model used: <class 'sklearn.neighbors.classification.KNeighborsClassifier'>
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.88      0.91      1648
#            1       0.89      0.95      0.92      1697
#
#     accuracy                           0.92      3345
#    macro avg       0.92      0.91      0.91      3345
# weighted avg       0.92      0.92      0.91      3345
#
# [[1446  202]
#  [  82 1615]]
#
# User: user107
#
# Model used: <class 'sklearn.ensemble.forest.RandomForestClassifier'>
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.96      1648
#            1       0.95      0.97      0.96      1697
#
#     accuracy                           0.96      3345
#    macro avg       0.96      0.96      0.96      3345
# weighted avg       0.96      0.96      0.96      3345
#
# [[1559   89]
#  [  57 1640]]
#
# User: user107
#
# Model used: <class 'sklearn.linear_model.logistic.LogisticRegression'>
#
#               precision    recall  f1-score   support
#
#            0       0.77      0.85      0.80      1648
#            1       0.83      0.75      0.79      1697
#
#     accuracy                           0.80      3345
#    macro avg       0.80      0.80      0.80      3345
# weighted avg       0.80      0.80      0.80      3345
#
# [[1394  254]
#  [ 426 1271]]
#
# User: user107
#
# Model used: <class 'sklearn.svm.classes.SVC'>
#
#               precision    recall  f1-score   support
#
#            0       0.49      1.00      0.66      1648
#            1       1.00      0.00      0.00      1697
#
#     accuracy                           0.49      3345
#    macro avg       0.75      0.50      0.33      3345
# weighted avg       0.75      0.49      0.33      3345
#
# [[1648    0]
#  [1696    1]]
#
# User: user109
#
# Model used: <class 'sklearn.neighbors.classification.KNeighborsClassifier'>
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.90      0.93       960
#            1       0.91      0.96      0.93       990
#
#     accuracy                           0.93      1950
#    macro avg       0.93      0.93      0.93      1950
# weighted avg       0.93      0.93      0.93      1950
#
# [[866  94]
#  [ 41 949]]
#
# User: user109
#
# Model used: <class 'sklearn.ensemble.forest.RandomForestClassifier'>
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97       960
#            1       0.97      0.98      0.97       990
#
#     accuracy                           0.97      1950
#    macro avg       0.97      0.97      0.97      1950
# weighted avg       0.97      0.97      0.97      1950
#
# [[929  31]
#  [ 22 968]]
#
# User: user109
#
# Model used: <class 'sklearn.linear_model.logistic.LogisticRegression'>
#
#               precision    recall  f1-score   support
#
#            0       0.87      0.98      0.92       960
#            1       0.98      0.85      0.91       990
#
#     accuracy                           0.92      1950
#    macro avg       0.92      0.92      0.92      1950
# weighted avg       0.93      0.92      0.92      1950
#
# [[945  15]
#  [146 844]]
#
# User: user109
#
# Model used: <class 'sklearn.svm.classes.SVC'>
#
#               precision    recall  f1-score   support
#
#            0       0.49      1.00      0.66       960
#            1       1.00      0.00      0.00       990
#
#     accuracy                           0.49      1950
#    macro avg       0.75      0.50      0.33      1950
# weighted avg       0.75      0.49      0.33      1950
#
# [[960   0]
#  [989   1]]

# %%
# what would output look like?
# what graphs are we going to do?
